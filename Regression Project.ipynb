# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/basha/OneDrive/Desktop/Route Ai Eng Basma Reda/Classification & Regression Project/regression_project_data.csv")

# %%
df
# Out:
#                  name                         full_name birth_date  age  \
# 0            L. Messi    Lionel Andrés Messi Cuccittini  6/24/1987   31
# 1          C. Eriksen      Christian  Dannemann Eriksen  2/14/1992   27
# 2            P. Pogba                        Paul Pogba  3/15/1993   25
# 3          L. Insigne                   Lorenzo Insigne   6/4/1991   27
# 4        K. Koulibaly                 Kalidou Koulibaly  6/20/1991   27
# ...               ...                               ...        ...  ...
# 17949     R. McKenzie                    Rory  McKenzie  10/7/1993   25
# 17950       M. Sipľak                     Michal Sipľak   2/2/1996   23
# 17951      J. Bekkema                       Jan Bekkema   4/9/1996   22
# 17952      A. Al Yami               Abdulrahman Al Yami  6/19/1997   21
# 17953  Júnior Brumado  José Francisco dos Santos Júnior  5/15/1999   19
#
#        height_cm  weight_kgs  positions   nationality  overall_rating  \
# 0         170.18        72.1   CF,RW,ST     Argentina              94
# 1         154.94        76.2  CAM,RM,CM       Denmark              88
# 2         190.50        83.9     CM,CAM        France              88
# 3         162.56        59.0      LW,ST         Italy              88
# 4         187.96        88.9         CB       Senegal              88
# ...          ...         ...        ...           ...             ...
# 17949     175.26        74.8  RM,CAM,CM      Scotland              67
# 17950     182.88        79.8         LB      Slovakia              59
# 17951     185.42        89.8         GK   Netherlands              59
# 17952     175.26        64.9      ST,LM  Saudi Arabia              59
# 17953     190.50        79.8         ST        Brazil              59
#
#        potential  ...  long_shots  aggression interceptions  positioning  \
# 0             94  ...          94          48            22           94
# 1             89  ...          89          46            56           84
# 2             91  ...          82          78            64           82
# 3             88  ...          84          34            26           83
# 4             91  ...          15          87            88           24
# ...          ...  ...         ...         ...           ...          ...
# 17949         70  ...          54          69            41           60
# 17950         67  ...          22          62            55           42
# 17951         67  ...           9          27            10            5
# 17952         71  ...          58          38            15           54
# 17953         75  ...          53          67            20           53
#
#        vision  penalties composure  marking standing_tackle  sliding_tackle
# 0          94         75        96       33              28              26
# 1          91         67        88       59              57              22
# 2          88         82        87       63              67              67
# 3          87         61        83       51              24              22
# 4          49         33        80       91              88              87
# ...       ...        ...       ...      ...             ...             ...
# 17949      64         63        56       40              20              18
# 17950      39         32        52       53              64              60
# 17951      25         16        47        9              12              13
# 17952      52         50        53       16              18              17
# 17953      49         52        45       23              31              21
#
# [17954 rows x 51 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr

# %%
df.head()
# Out:
#            name                       full_name birth_date  age  height_cm  \
# 0      L. Messi  Lionel Andrés Messi Cuccittini  6/24/1987   31     170.18
# 1    C. Eriksen    Christian  Dannemann Eriksen  2/14/1992   27     154.94
# 2      P. Pogba                      Paul Pogba  3/15/1993   25     190.50
# 3    L. Insigne                 Lorenzo Insigne   6/4/1991   27     162.56
# 4  K. Koulibaly               Kalidou Koulibaly  6/20/1991   27     187.96
#
#    weight_kgs  positions nationality  overall_rating  potential  ...  \
# 0        72.1   CF,RW,ST   Argentina              94         94  ...
# 1        76.2  CAM,RM,CM     Denmark              88         89  ...
# 2        83.9     CM,CAM      France              88         91  ...
# 3        59.0      LW,ST       Italy              88         88  ...
# 4        88.9         CB     Senegal              88         91  ...
#
#    long_shots  aggression interceptions  positioning  vision  penalties  \
# 0          94          48            22           94      94         75
# 1          89          46            56           84      91         67
# 2          82          78            64           82      88         82
# 3          84          34            26           83      87         61
# 4          15          87            88           24      49         33
#
#   composure  marking standing_tackle  sliding_tackle
# 0        96       33              28              26
# 1        88       59              57              22
# 2        87       63              67              67
# 3        83       51              24              22
# 4        80       91              88              87
#
# [5 rows x 51 columns]

# %%
df.tail()
# Out:
#                  name                         full_name birth_date  age  \
# 17949     R. McKenzie                    Rory  McKenzie  10/7/1993   25
# 17950       M. Sipľak                     Michal Sipľak   2/2/1996   23
# 17951      J. Bekkema                       Jan Bekkema   4/9/1996   22
# 17952      A. Al Yami               Abdulrahman Al Yami  6/19/1997   21
# 17953  Júnior Brumado  José Francisco dos Santos Júnior  5/15/1999   19
#
#        height_cm  weight_kgs  positions   nationality  overall_rating  \
# 17949     175.26        74.8  RM,CAM,CM      Scotland              67
# 17950     182.88        79.8         LB      Slovakia              59
# 17951     185.42        89.8         GK   Netherlands              59
# 17952     175.26        64.9      ST,LM  Saudi Arabia              59
# 17953     190.50        79.8         ST        Brazil              59
#
#        potential  ...  long_shots  aggression interceptions  positioning  \
# 17949         70  ...          54          69            41           60
# 17950         67  ...          22          62            55           42
# 17951         67  ...           9          27            10            5
# 17952         71  ...          58          38            15           54
# 17953         75  ...          53          67            20           53
#
#        vision  penalties composure  marking standing_tackle  sliding_tackle
# 17949      64         63        56       40              20              18
# 17950      39         32        52       53              64              60
# 17951      25         16        47        9              12              13
# 17952      52         50        53       16              18              17
# 17953      49         52        45       23              31              21
#
# [5 rows x 51 columns]

# %%
df.describe()
# Out:
#                 age     height_cm    weight_kgs  overall_rating     potential  \
# count  17954.000000  17954.000000  17954.000000    17954.000000  17954.000000
# mean      25.565445    174.946921     75.301047       66.240169     71.430935
# std        4.705708     14.029449      7.083684        6.963730      6.131339
# min       17.000000    152.400000     49.900000       47.000000     48.000000
# 25%       22.000000    154.940000     69.900000       62.000000     67.000000
# 50%       25.000000    175.260000     74.800000       66.000000     71.000000
# 75%       29.000000    185.420000     79.800000       71.000000     75.000000
# max       46.000000    205.740000    110.200000       94.000000     95.000000
#
#          value_euro      wage_euro  international_reputation(1-5)  \
# count  1.769900e+04   17708.000000                   17954.000000
# mean   2.479280e+06    9902.134628                       1.111674
# std    5.687014e+06   21995.593750                       0.392168
# min    1.000000e+04    1000.000000                       1.000000
# 25%    3.250000e+05    1000.000000                       1.000000
# 50%    7.000000e+05    3000.000000                       1.000000
# 75%    2.100000e+06    9000.000000                       1.000000
# max    1.105000e+08  565000.000000                       5.000000
#
#        weak_foot(1-5)  skill_moves(1-5)  ...    long_shots    aggression  \
# count    17954.000000      17954.000000  ...  17954.000000  17954.000000
# mean         2.945695          2.361034  ...     46.852456     55.816531
# std          0.663691          0.763223  ...     19.429337     17.394047
# min          1.000000          1.000000  ...      3.000000     11.000000
# 25%          3.000000          2.000000  ...     32.000000     44.000000
# 50%          3.000000          2.000000  ...     51.000000     59.000000
# 75%          3.000000          3.000000  ...     62.000000     69.000000
# max          5.000000          5.000000  ...     94.000000     95.000000
#
#        interceptions   positioning        vision     penalties     composure  \
# count   17954.000000  17954.000000  17954.000000  17954.000000  17954.000000
# mean       46.657959     49.857302     53.406260     48.357302     58.680183
# std        20.754649     19.694311     14.156038     15.810844     11.625541
# min         3.000000      2.000000     10.000000      5.000000     12.000000
# 25%        26.000000     38.000000     44.000000     38.000000     51.000000
# 50%        52.000000     55.000000     55.000000     49.000000     60.000000
# 75%        64.000000     64.000000     64.000000     60.000000     67.000000
# max        92.000000     95.000000     94.000000     92.000000     96.000000
#
#             marking  standing_tackle  sliding_tackle
# count  17954.000000     17954.000000    17954.000000
# mean      47.162861        47.733040       45.705915
# std       20.037346        21.674973       21.285812
# min        3.000000         2.000000        3.000000
# 25%       30.000000        27.000000       24.000000
# 50%       52.500000        55.000000       52.000000
# 75%       64.000000        66.000000       64.000000
# max       94.000000        93.000000       90.000000
#
# [8 rows x 42 columns]

# %%
df.isnull().sum()
# Out:
# name                                 0
# full_name                            0
# birth_date                           0
# age                                  0
# height_cm                            0
# weight_kgs                           0
# positions                            0
# nationality                          0
# overall_rating                       0
# potential                            0
# value_euro                         255
# wage_euro                          246
# preferred_foot                       0
# international_reputation(1-5)        0
# weak_foot(1-5)                       0
# skill_moves(1-5)                     0
# body_type                            0
# release_clause_euro               1837
# national_team                    17097
# national_rating                  17097
# national_team_position           17097
# national_jersey_number           17097
# crossing                             0
# finishing                            0
# heading_accuracy                     0
# short_passing                        0
# volleys                              0
# dribbling                            0
# curve                                0
# freekick_accuracy                    0
# long_passing                         0
# ball_control                         0
# acceleration                         0
# sprint_speed                         0
# agility                              0
# reactions                            0
# balance                              0
# shot_power                           0
# jumping                              0
# stamina                              0
# strength                             0
# long_shots                           0
# aggression                           0
# interceptions                        0
# positioning                          0
# vision                               0
# penalties                            0
# composure                            0
# marking                              0
# standing_tackle                      0
# sliding_tackle                       0
# dtype: int64

# %%
df.nunique()
# Out:
# name                             16995
# full_name                        17898
# birth_date                        6156
# age                                 29
# height_cm                           20
# weight_kgs                          57
# positions                          890
# nationality                        160
# overall_rating                      47
# potential                           47
# value_euro                         211
# wage_euro                          138
# preferred_foot                       2
# international_reputation(1-5)        5
# weak_foot(1-5)                       5
# skill_moves(1-5)                     5
# body_type                           10
# release_clause_euro               1248
# national_team                      103
# national_rating                     22
# national_team_position              29
# national_jersey_number              38
# crossing                            89
# finishing                           94
# heading_accuracy                    91
# short_passing                       85
# volleys                             88
# dribbling                           94
# curve                               89
# freekick_accuracy                   92
# long_passing                        84
# ball_control                        90
# acceleration                        86
# sprint_speed                        85
# agility                             82
# reactions                           68
# balance                             81
# shot_power                          91
# jumping                             74
# stamina                             86
# strength                            74
# long_shots                          92
# aggression                          85
# interceptions                       88
# positioning                         94
# vision                              85
# penalties                           87
# composure                           83
# marking                             91
# standing_tackle                     89
# sliding_tackle                      87
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17954 entries, 0 to 17953
# Data columns (total 51 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   name                           17954 non-null  object
#  1   full_name                      17954 non-null  object
#  2   birth_date                     17954 non-null  object
#  3   age                            17954 non-null  int64
#  4   height_cm                      17954 non-null  float64
#  5   weight_kgs                     17954 non-null  float64
#  6   positions                      17954 non-null  object
#  7   nationality                    17954 non-null  object
#  8   overall_rating                 17954 non-null  int64
#  9   potential                      17954 non-null  int64
#  10  value_euro                     17699 non-null  float64
#  11  wage_euro                      17708 non-null  float64
#  12  preferred_foot                 17954 non-null  object
#  13  international_reputation(1-5)  17954 non-null  int64
#  14  weak_foot(1-5)                 17954 non-null  int64
#  15  skill_moves(1-5)               17954 non-null  int64
#  16  body_type                      17954 non-null  object
#  17  release_clause_euro            16117 non-null  float64
#  18  national_team                  857 non-null    object
#  19  national_rating                857 non-null    float64
#  20  national_team_position         857 non-null    object
#  21  national_jersey_number         857 non-null    float64
#  22  crossing                       17954 non-null  int64
#  23  finishing                      17954 non-null  int64
#  24  heading_accuracy               17954 non-null  int64
#  25  short_passing                  17954 non-null  int64
#  26  volleys                        17954 non-null  int64
#  27  dribbling                      17954 non-null  int64
#  28  curve                          17954 non-null  int64
#  29  freekick_accuracy              17954 non-null  int64
#  30  long_passing                   17954 non-null  int64
#  31  ball_control                   17954 non-null  int64
#  32  acceleration                   17954 non-null  int64
#  33  sprint_speed                   17954 non-null  int64
#  34  agility                        17954 non-null  int64
#  35  reactions                      17954 non-null  int64
#  36  balance                        17954 non-null  int64
#  37  shot_power                     17954 non-null  int64
#  38  jumping                        17954 non-null  int64
#  39  stamina                        17954 non-null  int64
#  40  strength                       17954 non-null  int64
#  41  long_shots                     17954 non-null  int64
#  42  aggression                     17954 non-null  int64
#  43  interceptions                  17954 non-null  int64
#  44  positioning                    17954 non-null  int64
#  45  vision                         17954 non-null  int64
#  46  penalties                      17954 non-null  int64
#  47  composure                      17954 non-null  int64
#  48  marking                        17954 non-null  int64
#  49  standing_tackle                17954 non-null  int64
#  50  sliding_tackle                 17954 non-null  int64
# dtypes: float64(7), int64(35), object(9)
# memory usage: 7.0+ MB

# %%
df.columns.tolist()
# Out:
# ['name',
#  'full_name',
#  'birth_date',
#  'age',
#  'height_cm',
#  'weight_kgs',
#  'positions',
#  'nationality',
#  'overall_rating',
#  'potential',
#  'value_euro',
#  'wage_euro',
#  'preferred_foot',
#  'international_reputation(1-5)',
#  'weak_foot(1-5)',
#  'skill_moves(1-5)',
#  'body_type',
#  'release_clause_euro',
#  'national_team',
#  'national_rating',
#  'national_team_position',
#  'national_jersey_number',
#  'crossing',
#  'finishing',
#  'heading_accuracy',
#  'short_passing',
#  'volleys',
#  'dribbling',
#  'curve',
#  'freekick_accuracy',
#  'long_passing',
#  'ball_control',
#  'acceleration',
#  'sprint_speed',
#  'agility',
#  'reactions',
#  'balance',
#  'shot_power',
#  'jumping',
#  'stamina',
#  'strength',
#  'long_shots',
#  'aggression',
#  'interceptions',
#  'positioning',
#  'vision',
#  'penalties',
#  'composure',
#  'marking',
#  'standing_tackle',
#  'sliding_tackle']

# %% [markdown]
# # **Data Visualization**

# %%
x = df['age']
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(x)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
plt.figure(figsize=(40,8))
plt.title('Nationality Count Plot')
sns.countplot(x='nationality', data=df)
# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.show()

# %%
x = df['overall_rating']

# %%
# Create the distribution plot
sns.distplot(x)
plt.tilte('overall_rating')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 3
#       1 # Create the distribution plot
#       2 sns.distplot(x)
# ----> 3 plt.tilte('overall_rating')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'tilte'

# %%
# Create the scatter plot
ax = sns.scatterplot(x='potential', y='value_euro', data=df, hue='potential', size='value_euro', palette='cool', sizes=(20, 200), legend=False)

# Add a regression line
sns.regplot(x='potential', y='value_euro', data=df, scatter=False, ax=ax, color='blue')

# Set titles and labels
plt.title('Potential vs. Value Scatter Plot')
plt.xlabel('Potential')
plt.ylabel('Value')
# Out:
# Text(0, 0.5, 'Value')

# %% [markdown]
# # **Data preprocessing**

# %%
columns_to_drop = [
    'full_name', 'birth_date', 'nationality', 'value_euro', 'wage_euro', 
    'preferred_foot', 'release_clause_euro', 'national_team', 'national_rating', 
    'national_team_position', 'national_jersey_number'
]

# %%
df2 = df.drop(columns = columns_to_drop)

# %%
# Dataframe after dropping columns
df2
# Out:
#                  name  age  height_cm  weight_kgs  positions  overall_rating  \
# 0            L. Messi   31     170.18        72.1   CF,RW,ST              94
# 1          C. Eriksen   27     154.94        76.2  CAM,RM,CM              88
# 2            P. Pogba   25     190.50        83.9     CM,CAM              88
# 3          L. Insigne   27     162.56        59.0      LW,ST              88
# 4        K. Koulibaly   27     187.96        88.9         CB              88
# ...               ...  ...        ...         ...        ...             ...
# 17949     R. McKenzie   25     175.26        74.8  RM,CAM,CM              67
# 17950       M. Sipľak   23     182.88        79.8         LB              59
# 17951      J. Bekkema   22     185.42        89.8         GK              59
# 17952      A. Al Yami   21     175.26        64.9      ST,LM              59
# 17953  Júnior Brumado   19     190.50        79.8         ST              59
#
#        potential  international_reputation(1-5)  weak_foot(1-5)  \
# 0             94                              5               4
# 1             89                              3               5
# 2             91                              4               4
# 3             88                              3               4
# 4             91                              3               3
# ...          ...                            ...             ...
# 17949         70                              1               3
# 17950         67                              1               3
# 17951         67                              1               1
# 17952         71                              1               4
# 17953         75                              1               4
#
#        skill_moves(1-5)  ... long_shots  aggression  interceptions  \
# 0                     4  ...         94          48             22
# 1                     4  ...         89          46             56
# 2                     5  ...         82          78             64
# 3                     4  ...         84          34             26
# 4                     2  ...         15          87             88
# ...                 ...  ...        ...         ...            ...
# 17949                 3  ...         54          69             41
# 17950                 2  ...         22          62             55
# 17951                 1  ...          9          27             10
# 17952                 3  ...         58          38             15
# 17953                 2  ...         53          67             20
#
#        positioning  vision  penalties  composure  marking  standing_tackle  \
# 0               94      94         75         96       33               28
# 1               84      91         67         88       59               57
# 2               82      88         82         87       63               67
# 3               83      87         61         83       51               24
# 4               24      49         33         80       91               88
# ...            ...     ...        ...        ...      ...              ...
# 17949           60      64         63         56       40               20
# 17950           42      39         32         52       53               64
# 17951            5      25         16         47        9               12
# 17952           54      52         50         53       16               18
# 17953           53      49         52         45       23               31
#
#        sliding_tackle
# 0                  26
# 1                  22
# 2                  67
# 3                  22
# 4                  87
# ...               ...
# 17949              18
# 17950              60
# 17951              13
# 17952              17
# 17953              21
#
# [17954 rows x 40 columns]

# %%
df2.isnull().sum()
# Out:
# name                             0
# age                              0
# height_cm                        0
# weight_kgs                       0
# positions                        0
# overall_rating                   0
# potential                        0
# international_reputation(1-5)    0
# weak_foot(1-5)                   0
# skill_moves(1-5)                 0
# body_type                        0
# crossing                         0
# finishing                        0
# heading_accuracy                 0
# short_passing                    0
# volleys                          0
# dribbling                        0
# curve                            0
# freekick_accuracy                0
# long_passing                     0
# ball_control                     0
# acceleration                     0
# sprint_speed                     0
# agility                          0
# reactions                        0
# balance                          0
# shot_power                       0
# jumping                          0
# stamina                          0
# strength                         0
# long_shots                       0
# aggression                       0
# interceptions                    0
# positioning                      0
# vision                           0
# penalties                        0
# composure                        0
# marking                          0
# standing_tackle                  0
# sliding_tackle                   0
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17954 entries, 0 to 17953
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   name                           17954 non-null  object
#  1   age                            17954 non-null  int64
#  2   height_cm                      17954 non-null  float64
#  3   weight_kgs                     17954 non-null  float64
#  4   positions                      17954 non-null  object
#  5   overall_rating                 17954 non-null  int64
#  6   potential                      17954 non-null  int64
#  7   international_reputation(1-5)  17954 non-null  int64
#  8   weak_foot(1-5)                 17954 non-null  int64
#  9   skill_moves(1-5)               17954 non-null  int64
#  10  body_type                      17954 non-null  object
#  11  crossing                       17954 non-null  int64
#  12  finishing                      17954 non-null  int64
#  13  heading_accuracy               17954 non-null  int64
#  14  short_passing                  17954 non-null  int64
#  15  volleys                        17954 non-null  int64
#  16  dribbling                      17954 non-null  int64
#  17  curve                          17954 non-null  int64
#  18  freekick_accuracy              17954 non-null  int64
#  19  long_passing                   17954 non-null  int64
#  20  ball_control                   17954 non-null  int64
#  21  acceleration                   17954 non-null  int64
#  22  sprint_speed                   17954 non-null  int64
#  23  agility                        17954 non-null  int64
#  24  reactions                      17954 non-null  int64
#  25  balance                        17954 non-null  int64
#  26  shot_power                     17954 non-null  int64
#  27  jumping                        17954 non-null  int64
#  28  stamina                        17954 non-null  int64
#  29  strength                       17954 non-null  int64
#  30  long_shots                     17954 non-null  int64
#  31  aggression                     17954 non-null  int64
#  32  interceptions                  17954 non-null  int64
#  33  positioning                    17954 non-null  int64
#  34  vision                         17954 non-null  int64
#  35  penalties                      17954 non-null  int64
#  36  composure                      17954 non-null  int64
#  37  marking                        17954 non-null  int64
#  38  standing_tackle                17954 non-null  int64
#  39  sliding_tackle                 17954 non-null  int64
# dtypes: float64(2), int64(35), object(3)
# memory usage: 5.5+ MB

# %%
df2['body_type'].value_counts()
# Out:
# body_type
# Normal                 10393
# Lean                    6468
# Stocky                  1086
# Messi                      1
# Courtois                   1
# PLAYER_BODY_TYPE_25        1
# Akinfenwa                  1
# Shaqiri                    1
# Neymar                     1
# C. Ronaldo                 1
# Name: count, dtype: int64

# %% [markdown]
# # **Label Encoding**

# %%
# Apply Label Encoding to categorical columns
label_encoder = LabelEncoder()

# %%
df2['name_encoder'] = label_encoder.fit_transform(df2['name'])

# %%
df2['positions_encoder'] = label_encoder.fit_transform(df2['positions'])

# %%
df2['body_type_encoder'] = label_encoder.fit_transform(df2['body_type'])

# %%
# Apply LabelEncoder to each categorical column
for col in df2.select_dtypes(include=['object', 'category']).columns:
    df2[col] = label_encoder.fit_transform(df2[col])

# %%
print(df2)
# Out:
#         name  age  height_cm  weight_kgs  positions  overall_rating  \
# 0       9536   31     170.18        72.1        214              94
# 1       2446   27     154.94        76.2         72              88
# 2      13031   25     190.50        83.9        228              88
# 3       9421   27     162.56        59.0        549              88
# 4       8675   27     187.96        88.9        104              88
# ...      ...  ...        ...         ...        ...             ...
# 17949  13723   25     175.26        74.8        648              67
# 17950  11415   23     182.88        79.8        328              59
# 17951   6835   22     185.42        89.8        327              59
# 17952    100   21     175.26        64.9        845              59
# 17953   8424   19     190.50        79.8        823              59
#
#        potential  international_reputation(1-5)  weak_foot(1-5)  \
# 0             94                              5               4
# 1             89                              3               5
# 2             91                              4               4
# 3             88                              3               4
# 4             91                              3               3
# ...          ...                            ...             ...
# 17949         70                              1               3
# 17950         67                              1               3
# 17951         67                              1               1
# 17952         71                              1               4
# 17953         75                              1               4
#
#        skill_moves(1-5)  ...  positioning  vision  penalties  composure  \
# 0                     4  ...           94      94         75         96
# 1                     4  ...           84      91         67         88
# 2                     5  ...           82      88         82         87
# 3                     4  ...           83      87         61         83
# 4                     2  ...           24      49         33         80
# ...                 ...  ...          ...     ...        ...        ...
# 17949                 3  ...           60      64         63         56
# 17950                 2  ...           42      39         32         52
# 17951                 1  ...            5      25         16         47
# 17952                 3  ...           54      52         50         53
# 17953                 2  ...           53      49         52         45
#
#        marking  standing_tackle  sliding_tackle  name_encoder  \
# 0           33               28              26          9536
# 1           59               57              22          2446
# 2           63               67              67         13031
# 3           51               24              22          9421
# 4           91               88              87          8675
# ...        ...              ...             ...           ...
# 17949       40               20              18         13723
# 17950       53               64              60         11415
# 17951        9               12              13          6835
# 17952       16               18              17           100
# 17953       23               31              21          8424
#
#        positions_encoder  body_type_encoder
# 0                    214                  4
# 1                     72                  3
# 2                    228                  6
# 3                    549                  6
# 4                    104                  6
# ...                  ...                ...
# 17949                648                  6
# 17950                328                  6
# 17951                327                  6
# 17952                845                  3
# 17953                823                  6
#
# [17954 rows x 43 columns]

# %%
# Specify the target coulmn
target_column = 'overall_rating'

# %%
# Seprate features and target
X = df2.drop(columns=[target_column]) # Feature
Y = df2[target_column]

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# # **Regression Models**

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor

# %%
# Initialize and train each regression model
models = {
    'Linear Regression': LinearRegression(),
    'KNN Regression': KNeighborsRegressor(),
    'SVR': SVR(),
    'Random Forest': RandomForestRegressor(),
    'AdaBoost': AdaBoostRegressor(base_estimator=DecisionTreeRegressor()),
}

# %%
# Train and evaluate each model
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    print(f"{name} Mean Squared Error: {mse:.2f}")
# Out:
# Linear Regression Mean Squared Error: 4.20
# KNN Regression Mean Squared Error: 28.88
# SVR Mean Squared Error: 48.46
# Random Forest Mean Squared Error: 1.34
# AdaBoost Mean Squared Error: 1.31
